# %% [markdown]
# # Assignment 1: Happiness
# ### Name: Vinay Haresh Bojja
# #### Instruction:
# * Install xlrd library using the command: pip3 install xlrd.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read Excel file 
df = pd.read_excel('DataForTable2.1WHR2023.xls')
df
# Out:
# /var/folders/fq/nclhl23j55s570qj6dfkqgq80000gn/T/ipykernel_86141/2524237607.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2199 non-null   object
#  1   year                              2199 non-null   int64
#  2   Life Ladder                       2199 non-null   float64
#  3   Log GDP per capita                2179 non-null   float64
#  4   Social support                    2186 non-null   float64
#  5   Healthy life expectancy at birth  2145 non-null   float64
#  6   Freedom to make life choices      2166 non-null   float64
#  7   Generosity                        2126 non-null   float64
#  8   Perceptions of corruption         2083 non-null   float64
#  9   Positive affect                   2175 non-null   float64
#  10  Negative affect                   2183 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %% [markdown]
# #### Question 1.a) What is your evaluation of the quality of the data?
# #### Answer 1.a)
# * The data has in total 2199 rows. Some columns such as "Log GDP per capita", "Social support", "Healthy life expectancy at birth", "Freedom to make life choice", "Generosity", "Perceptions of corruption", "Positive affect" and "Negative affect" have null values in them. Hence, I think some data is lost.
# * In the pdf "https://happiness-report.s3.amazonaws.com/2023/WHR+23_Statistical_Appendix.pdf" page 2 line 11, it says that this column represents the answer to the question “Have you donated money to a charity in the past month?”. I think there can only be 2 answers 1 or 0 but the column contains some negative values.

# %%
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018     3.616480            7.783066        0.775388
# 2195     Zimbabwe  2019     2.693523            7.697755        0.759162
# 2196     Zimbabwe  2020     3.159802            7.596050        0.717243
# 2197     Zimbabwe  2021     3.154578            7.656878        0.685151
# 2198     Zimbabwe  2022     3.296220            7.670123        0.666172
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# #### Question 1.b) How large is the dataset?
# #### Answer 1.b)
# * The dataset has 2199 rows and 11 columns.

# %% [markdown]
# #### Question 1.c) What are the features (columns) and how are they represented?
# #### Answer 1.c)
# * The features are as listed below:
#     * Country name -
#        * DataType - object
#        * Desc - Name of the country.
#     * year -
#        * Datatype - int64
#        * Desc - Year the data was collected from.
#     * Life Ladder -
#        * Datatype - float64
#        * Desc - Imagine a ladder with steps in a range of 0 to 10, with 0 being the worst and 10 being the best possible life.
#     * Log GDP per capita -
#        * Datatype - float64
#        * Desc - GDP of the country for that particular year.
#     * Social support -
#        * Datatype - float64
#        * Desc - Average of responses(0s or 1s) from the people, when asked whether they had a relative or a friend to help when they needed them in trouble.
#     * Healthy life expectancy at birth -
#        * Datatype - float64
#        * Desc - Mean of number of years a person is expected to live in full health at birth.
#     * Freedom to make life choices -
#        * Datatype - float64
#        * Desc - Average of responses(0s or 1s) from the people, when asked whether they were satisfied with the freedom to choose what they want in their life.
#     * Generosity -
#        * Datatype - float64
#        * Desc - Average of responses(0s or 1s) from the people, when asked whether they donated money to the charity in the last month.
#     * Perceptions of corruption -
#        * Datatype - float64
#        * Desc - Average of responses(0s or 1s) from the people, when asked whether corruption is widespread throughout the government or not, or if it was widespread throughout the businesses or not.
#     * Positive affect -
#        * Datatype - float64
#        * Desc - Average of responses(0s or 1s) from the people, when asked whether they laughed, enjoyed, or did some interesting           things.
#     * Negative affect -
#        * Datatype - float64
#        * Desc - Average of responses (0s or 1s) from the people upon asking whether they were worried, sad, or angry.
# (Reference: John F. Helliwell, Haifang Huang, Max Norton, Shun Wang and Leonard Gof. https://happiness-report.s3.amazonaws.com/2023/WHR+23_Statistical_Appendix.pdf. 1-2)

# %%
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2199.000000  2199.000000         2179.000000     2186.000000
# mean   2014.161437     5.479226            9.389766        0.810679
# std       4.718736     1.125529            1.153387        0.120952
# min    2005.000000     1.281271            5.526723        0.228217
# 25%    2010.000000     4.646750            8.499764        0.746609
# 50%    2014.000000     5.432437            9.498955        0.835535
# 75%    2018.000000     6.309460           10.373216        0.904792
# max    2022.000000     8.018934           11.663788        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2145.000000                   2166.000000
# mean                          63.294583                      0.747858
# std                            6.901104                      0.140150
# min                            6.720000                      0.257534
# ...

# %% [markdown]
# #### Question 1.d) Are there any interesting distributions in the (numeric) features?
# #### Answer 1.d)
# *
#     * Life Ladder - The countries exhibit a range of life ladder, with the minimum being 1.28, the maximum reaching 8.01, and the average settling at 5.47. This suggests that countries experience a balance between relatively favorable and challenging life circumstances.
#     * Log GDP per capita - Highest GDP observed is 11.66 while the lowest is 5.52.
#     * Social support - Around 81% countries had social support from their relatives or friends when in trouble.
#     * Freedom to make life choices - On an average, 74% of countries had the freedom to make life choices with the max being 98%.
#     * Perception of corruption - In the country, approximately 3% of the population believes that corruption is widespread, while the highest percentage of people who perceive the country as corruption-free is around 98%.
#     * Positive affect - On an average, 65% of the countries engaged in laughter, enjoyment, and activities they found interesting.
#     * Negative affect - In a country, only 8% of the population reported feeling worried, sad, or angry, indicating that it had the least negative impact on their lives.

# %%
fig, axs = plt.subplots(nrows=3, ncols=3, figsize = (15,4))
sns.histplot(df['Life Ladder'], kde=True, ax=axs[0,0])
sns.histplot(df['Log GDP per capita'], kde=True, ax=axs[0, 1])
sns.histplot(df['Social support'], kde=True, ax=axs[0, 2])
sns.histplot(df['Healthy life expectancy at birth'], kde=True, ax=axs[1,0])
sns.histplot(df['Freedom to make life choices'], kde=True, ax=axs[1, 1])
sns.histplot(df['Generosity'], kde=True, ax=axs[1,2])
sns.histplot(df['Perceptions of corruption'], kde=True, ax=axs[2, 0])
sns.histplot(df['Positive affect'], kde=True, ax=axs[2,1])
sns.histplot(df['Negative affect'], kde=True, ax=axs[2,2])

plt.show()

# %%
life_ladder_skew = df['Life Ladder'].skew()
life_ladder_kurt = df['Life Ladder'].kurt()

GDP_per_capita_skew = df['Log GDP per capita'].skew()
GDP_per_capita_kurt = df['Log GDP per capita'].kurt()

social_support_skew = df['Social support'].skew()
social_support_kurt = df['Social support'].kurt()

healthy_life_expectancy_skew = df['Healthy life expectancy at birth'].skew()
healthy_life_expectancy_kurt = df['Healthy life expectancy at birth'].kurt()

freedom_to_make_life_skew = df['Freedom to make life choices'].skew()
freedom_to_make_life_kurt = df['Freedom to make life choices'].kurt()

generosity_skew = df['Generosity'].skew()
generosity_kurt = df['Generosity'].kurt()

perceptions_of_corruption_skew = df['Perceptions of corruption'].skew()
perceptions_of_corruption_kurt = df['Perceptions of corruption'].kurt()

positive_affect_skew = df['Positive affect'].skew()
positive_affect_kurt = df['Positive affect'].kurt()

negative_affect_skew = df['Negative affect'].skew()
negative_affect_kurt = df['Negative affect'].kurt()

print(f"                                       Skew                              kurt")
print(f"Life Ladder:                      {life_ladder_skew}          {life_ladder_kurt}")
print(f"Log GDP per capita:               {GDP_per_capita_skew}           {GDP_per_capita_kurt}")
print(f"Social support':                  {social_support_skew}            {social_support_kurt}")
print(f"Healthy life expectancy at birth: {healthy_life_expectancy_skew}            {healthy_life_expectancy_kurt}")
print(f"Freedom to make life choices:     {freedom_to_make_life_skew}             {freedom_to_make_life_kurt}")
print(f"Generosity:                       {generosity_skew}             {generosity_kurt}")
print(f"Perceptions of corruption:        {perceptions_of_corruption_skew}            {perceptions_of_corruption_kurt}")
print(f"Positive affect:                  {positive_affect_skew}           {positive_affect_kurt}")
print(f"Negative affect:                  {negative_affect_skew}              {negative_affect_kurt}")
# Out:
#                                        Skew                              kurt
# Life Ladder:                      -0.017819331787346102          -0.5918479723083578
# Log GDP per capita:               -0.33512982276196995           -0.7730364850582307
# Social support':                  -1.1188344045866705            1.1739089147806463
# Healthy life expectancy at birth: -1.1454543057254836            2.9896602355599575
# Freedom to make life choices:     -0.6705383696711781             -0.03478504567633589
# Generosity:                       0.7770869685066418             0.8315897969858366
# Perceptions of corruption:        -1.4904178416399556            1.814231483430651
# Positive affect:                  -0.43620485037840157           -0.20781810467888429
# Negative affect:                  0.731082575316055              0.7573999281385189

# %% [markdown]
# * Life Ladder:
# Skewness (-0.018) suggests a slight negative skew.
# Kurtosis (-0.592) indicates a relatively flat distribution with moderate tails.
#
# * Log GDP per capita:
# Negative skewness (-0.335) suggests a slight leftward tail.
# Kurtosis (-0.773) indicates a flatter distribution with light tails.
#
# * Social Support:
# Significant negative skewness (-1.119) indicates a long tail to the left.
# Positive kurtosis (1.174) suggests heavier tails and a peaked distribution.
#
# * Healthy Life Expectancy at Birth:
# Strong negative skewness (-1.145) indicates a longer tail to the left.
# High positive kurtosis (2.990) suggests a distribution with heavy tails and a pronounced peak.
#
# * Freedom to Make Life Choices:
# Negative skewness (-0.671) indicates a slight leftward tail.
# Almost normal kurtosis (-0.035) suggests a distribution close to normal.
#
# * Generosity:
# Positive skewness (0.777) suggests a longer tail to the right.
# Positive kurtosis (0.832) indicates a distribution with heavier tails and a peak.
#
# * Perceptions of Corruption:
# Strong negative skewness (-1.490) indicates a long tail to the left.
# Positive kurtosis (1.814) suggests a distribution with heavy tails and a peak.
#
# * Positive Affect:
# Negative skewness (-0.436) indicates a slight leftward tail.
# Almost normal kurtosis (-0.208) suggests a distribution close to normal.
#
# * Negative Affect:
# Positive skewness (0.731) suggests a longer tail to the right.
# Positive kurtosis (0.757) indicates a distribution with heavier tails and a peak.

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize = (20,4))
sns.histplot(df['Life Ladder'], ax=axs[0])
sns.histplot(df['Log GDP per capita'], ax=axs[1])
sns.histplot(df['Positive affect'], ax=axs[2])
sns.histplot(df['Negative affect'], ax=axs[3])
sns.histplot(df['Generosity'], ax=axs[4])
plt.show()

# %%
df.hist(bins=50, figsize=(20,8))
plt.show()

# %%
sns.heatmap(df.drop(['Country name'], axis=1).corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %% [markdown]
# #### Question 1.e) Are there any interesting correlations in the data?
# #### Answer 1.e)
#
# * Highest correlation is between healthy life expectancy at birth and Log GDP per capita.
# * Second highest correlation is between Log GDP per capita and the Life ladder. This indicates that an increase or decrease in GDP should affect the happiness of the country.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2199 non-null   object
#  1   year                              2199 non-null   int64
#  2   Life Ladder                       2199 non-null   float64
#  3   Log GDP per capita                2179 non-null   float64
#  4   Social support                    2186 non-null   float64
#  5   Healthy life expectancy at birth  2145 non-null   float64
#  6   Freedom to make life choices      2166 non-null   float64
#  7   Generosity                        2126 non-null   float64
#  8   Perceptions of corruption         2083 non-null   float64
#  9   Positive affect                   2175 non-null   float64
#  10  Negative affect                   2183 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %% [markdown]
# #### Question 1.f) Can you identify any limitations, missing values or distortions of the data?
# #### Answer 1.f)
# * Some columns such as "Log GDP per capita", "Social support", "Healthy life expectancy at birth", "Freedom to make life choice", "Generosity", "Perceptions of corruption", "Positive affect" and "Negative affect" have null values in them.

# %% [markdown]
# #### Question 1.g What would you like to see in this dataset?
# #### Answer 1.g)
#
# * Crime index
# * People visiting hospitals
# * Cultural backwardness
# * Insurance

# %%
#Happiest Country of 2022
happiest_country_2022_df = df[df['year'] == 2022]
happiest_country_2022_df = happiest_country_2022_df[happiest_country_2022_df['Life Ladder']> 7.1]
happiest_country_2022_df = happiest_country_2022_df.sort_values('Life Ladder')
happiest_country_2022 = happiest_country_2022_df.iloc[-1]['Country name']
happiest_country_2022

#Plot the graph and print the answer
print(f"Happiest country of 2022 is: {happiest_country_2022}")
sns.scatterplot(data = happiest_country_2022_df, x=happiest_country_2022_df['Life Ladder'], y=happiest_country_2022_df['Country name'])
# Out:
# Happiest country of 2022 is: Finland
# <Axes: xlabel='Life Ladder', ylabel='Country name'>

# %% [markdown]
# #### Question 2.a) What is the happiest country in 2022?
# #### Answer 2.a) Finland

# %%
#Happiest country in 2013
happiest_country_2013_df = df[df['year'] == 2013]
happiest_country_2013_df = happiest_country_2013_df[happiest_country_2013_df['Life Ladder']> 7]
happiest_country_2013_df = happiest_country_2013_df.sort_values('Life Ladder')
happiest_country_2013 = happiest_country_2013_df.iloc[-1]['Country name']
happiest_country_2013
happiest_country_2013_df
# Plot the graph and print the results
# print(f"Happiest country in 2013: {happiest_country_2013}")
# sns.scatterplot(data = happiest_country_2013_df, x=happiest_country_2013_df['Life Ladder'], y=happiest_country_2013_df['Country name'])
# Out:
#        Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 169         Belgium  2013     7.103661           10.783210        0.909186
# 1159     Luxembourg  2013     7.130809           11.635592        0.916683
# 249          Brazil  2013     7.140283            9.664690        0.910422
# 450      Costa Rica  2013     7.158000            9.800621        0.902069
# 2078  United States  2013     7.249285           10.940915        0.925397
# 1402    New Zealand  2013     7.280152           10.584589        0.958153
# 916          Israel  2013     7.320563           10.503324        0.908516
# 82        Australia  2013     7.364169           10.752455        0.928205
# 1386    Netherlands  2013     7.406550           10.852054        0.924705
# 1856         Sweden  2013     7.434011           10.788539        0.915648
# 1268         Mexico  2013     7.442546            9.843951        0.759138
# ...

# %% [markdown]
# #### Question 2.b) In 2013?
# #### Answer 2.b) Canada

# %%
# Happiest country of all time
happy_country_allTime_df = df[df['Life Ladder']> 7.5]
happy_country_allTime_df = happy_country_allTime_df.sort_values('Life Ladder')
happy_country_allTime = happy_country_allTime_df.iloc[-1]['Country name']

# Plot the graph and print the results
sns.scatterplot(data = happy_country_allTime_df, x=happy_country_allTime_df['Life Ladder'], y=happy_country_allTime_df['Country name'])
print(f"Happiest country of all time is: {happy_country_allTime}")
# Out:
# Happiest country of all time is: Denmark

# %% [markdown]
# #### Question 2.c) Of all time?
# #### Answer 2.c) Denmark

# %%
#Least happy country in 2022
least_happy_country_2022_df = df[df['year'] == 2022]
least_happy_country_2022_df = least_happy_country_2022_df[least_happy_country_2022_df['Life Ladder'] < 4]
least_happy_country_2022_df = least_happy_country_2022_df.sort_values('Life Ladder')
least_happy_country_2022 = least_happy_country_2022_df.iloc[0]['Country name']

#Plot the graph and print the results
sns.scatterplot(data = least_happy_country_2022_df, x=least_happy_country_2022_df['Life Ladder'], y=least_happy_country_2022_df['Country name'])
print(f"Least happy country in 2022 is: {least_happy_country_2022}")
# Out:
# Least happy country in 2022 is: Afghanistan

# %%
#Least happy country in 2013
least_happy_country_2013_df = df[df['year'] == 2013]
least_happy_country_2013_df = least_happy_country_2013_df[least_happy_country_2013_df['Life Ladder']< 4]
least_happy_country_2013_df = least_happy_country_2013_df.sort_values('Life Ladder')
least_happy_country_2013 = least_happy_country_2013_df.iloc[0]['Country name']

# Plot the graph and print the results
sns.scatterplot(data = least_happy_country_2013_df, x=least_happy_country_2013_df['Life Ladder'], y=least_happy_country_2013_df['Country name'])
print(f"Least happy country in 2013 is: {least_happy_country_2013}")
# Out:
# Least happy country in 2013 is: Syria

# %%
#All time Least happy country
all_time_least_happy_country_df = df[df['Life Ladder'] < 3]
all_time_least_happy_country_df = all_time_least_happy_country_df.sort_values('Life Ladder')
all_time_least_happy_country = all_time_least_happy_country_df.iloc[0]['Country name']

# Plot the graph and print the results
sns.scatterplot(data = all_time_least_happy_country_df, x=all_time_least_happy_country_df['Life Ladder'], y=all_time_least_happy_country_df['Country name'])
print(f"All time least happy country is: {all_time_least_happy_country}")
# Out:
# All time least happy country is: Afghanistan

# %% [markdown]
# #### Question 2.d) What is the least happy country in 2022, 2013 and of all time?
# #### Answer 2.d)
# * i)The least happy country in 2022 is Afghanistan.
# * ii) The least happy country in 2013 is Syria.
# * iii) All time least happy country is Afghanistan.

# %%
# Find the difference in Life Ladder from the first year to 2022
df['HappinessIncrease'] = df.groupby('Country name')['Life Ladder'].transform(lambda x: x.iloc[-1] - x.iloc[0])

# Create a new DataFrame with only 'Country name' and 'HappinessIncrease'
result_df = df[['Country name', 'HappinessIncrease']].drop_duplicates()

#sort value by HappinessIncrease
result_df = result_df.sort_values('HappinessIncrease')
# result_df
#store max and minimum increase values in variable
max_increase_country = result_df.iloc[-1]['Country name']
min_increase_country = result_df.iloc[0]['Country name']

print(f"The country with the largest increase in happiness is: {max_increase_country}")
print(f"The country with the minimum increase in happiness is: {min_increase_country}")
# Out:
# The country with the largest increase in happiness is: Congo (Brazzaville)
# The country with the minimum increase in happiness is: Lebanon

# %% [markdown]
# #### Question 3) Of the countries in this dataset, which country had the largest increase in happiness from its start of participation to 2022? Which had the largest decrease in happiness?
# #### Answer 3.)
# * The country with the largest increase in happiness is: Congo (Brazzaville)
# * The country with the minimum increase in happiness is: Lebanon
